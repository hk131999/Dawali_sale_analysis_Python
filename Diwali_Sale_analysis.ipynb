# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Diwali Sales Data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
data.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
data.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
data
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra�Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount
# 0      23952.0
# 1      23934.0
# 2      23924.0
# 3      23912.0
# 4      23877.0
# ...        ...
# 11246    370.0
# 11247    367.0
# 11248    213.0
# 11249    206.0
# 11250    188.0
#
# [11251 rows x 13 columns]

# %%
data.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data['Marital_Status']=data['Marital_Status'].replace([1,0],['Married','Not Married'])

# %%
data
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28    Not Married
# 1      1000732       Kartik  P00110942      F     26-35   35        Married
# 2      1001990        Bindu  P00118542      F     26-35   35        Married
# 3      1001425       Sudevi  P00237842      M      0-17   16    Not Married
# 4      1000588         Joni  P00057942      M     26-35   28        Married
# ...        ...          ...        ...    ...       ...  ...            ...
# 11246  1000695      Manning  P00296942      M     18-25   19        Married
# 11247  1004089  Reichenbach  P00171342      M     26-35   33    Not Married
# 11248  1001209        Oshin  P00201342      F     36-45   40    Not Married
# 11249  1004023       Noonan  P00059442      M     36-45   37    Not Married
# 11250  1002744      Brumley  P00281742      F     18-25   19    Not Married
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra�Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount
# 0      23952.0
# 1      23934.0
# 2      23924.0
# 3      23912.0
# 4      23877.0
# ...        ...
# 11246    370.0
# 11247    367.0
# 11248    213.0
# 11249    206.0
# 11250    188.0
#
# [11239 rows x 13 columns]

# %%
fig,ax=plt.subplots(1,2)
fig.set_figwidth(40)
fig.set_figheight(10)
sns.set(font_scale=1)
sns.countplot(x=data.Gender,data=data,ax=ax[0])
sns.countplot(x='Gender',data=data,hue='Marital_Status',ax=ax[1])
Inf_Gender=pd.DataFrame()
Inf_Gender['Gender']=['F','M']
Inf_Gender['Count']=[data['Gender'].value_counts()[0],data['Gender'].value_counts()[1]]
print(data['Gender'].value_counts())
# Out:
# F    7832
# M    3407
# Name: Gender, dtype: int64

# %%
Total_amount=pd.DataFrame()
Total_amount=data.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

print(Total_amount)
sns.barplot(x='Gender',y='Amount',data=Total_amount)


Inf_Gender['Amount']=Total_amount['Amount']
Inf_Gender['Avg Sale']=Inf_Gender['Amount']/Inf_Gender['Count']
Inf_Gender['Percentage_Contributation']=[(Inf_Gender['Amount'][0]/(Inf_Gender['Amount'].sum()))*100,(Inf_Gender['Amount'][1]/(Inf_Gender['Amount'].sum()))*100]
# Out:
#   Gender       Amount
# 0      F  74335856.43
# 1      M  31913276.00

# %%
ax=sns.countplot(x='Age Group', data=data,hue='Gender')

# %%
Age_group_info=data.groupby(['Age Group','Gender'],as_index=False)['Amount'].sum().sort_values(by=['Amount'], ascending=False)
Age_group_info['Count']=(data.groupby(['Age Group','Gender'],as_index=False)['Gender'].size()).iloc[:,2]
Age_group_info['Avg Amount']=Age_group_info['Amount']/Age_group_info['Count']
Age_group_info['Percentage Contributation']=(Age_group_info['Amount']/Age_group_info['Amount'].sum())*100

# %%
fig,ax=plt.subplots(1,2)
fig.set_figwidth(50)
fig.set_figheight(20)
sns.set(font_scale=1.5)
sns.barplot(x='Age Group',y='Amount',data=Age_group_info,hue='Gender',ax=ax[0])
sns.barplot(x='Gender',y='Amount',data=data,hue='Product_Category',ax=ax[1],palette='tab10')
Age_group_info.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_89fb2_" ><thead>    <tr>        <th class="col_heading level0 col0" >Age Group</th>        <th class="col_heading level0 col1" >Gender</th>        <th class="col_heading level0 col2" >Amount</th>        <th class="col_heading level0 col3" >Count</th>        <th class="col_heading level0 col4" >Avg Amount</th>        <th class="col_heading level0 col5" >Percentage Contributation</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_89fb2_row0_col0" class="data row0 col0" >26-35</td>
#                         <td id="T_89fb2_row0_col1" class="data row0 col1" >F</td>
#                         <td id="T_89fb2_row0_col2" class="data row0 col2" >30963954.940000</td>
#                         <td id="T_89fb2_row0_col3" class="data row0 col3" >3269</td>
#                         <td id="T_89fb2_row0_col4" class="data row0 col4" >9471.996005</td>
#                         <td id="T_89fb2_row0_col5" class="data row0 col5" >29.142784</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row1_col0" class="data row1 col0" >36-45</td>
#                         <td id="T_89fb2_row1_col1" class="data row1 col1" >F</td>
#                         <td id="T_89fb2_row1_col2" class="data row1 col2" >15509957.490000</td>
#                         <td id="T_89fb2_row1_col3" class="data row1 col3" >1578</td>
#                         <td id="T_89fb2_row1_col4" class="data row1 col4" >9828.870399</td>
#                         <td id="T_89fb2_row1_col5" class="data row1 col5" >14.597726</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row2_col0" class="data row2 col0" >18-25</td>
#                         <td id="T_89fb2_row2_col1" class="data row2 col1" >F</td>
#                         <td id="T_89fb2_row2_col2" class="data row2 col2" >11887003.000000</td>
#                         <td id="T_89fb2_row2_col3" class="data row2 col3" >1305</td>
#                         <td id="T_89fb2_row2_col4" class="data row2 col4" >9108.814559</td>
#                         <td id="T_89fb2_row2_col5" class="data row2 col5" >11.187859</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row3_col0" class="data row3 col0" >26-35</td>
#                         <td id="T_89fb2_row3_col1" class="data row3 col1" >M</td>
#                         <td id="T_89fb2_row3_col2" class="data row3 col2" >11649489.000000</td>
#                         <td id="T_89fb2_row3_col3" class="data row3 col3" >1272</td>
#                         <td id="T_89fb2_row3_col4" class="data row3 col4" >9158.403302</td>
#                         <td id="T_89fb2_row3_col5" class="data row3 col5" >10.964314</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row4_col0" class="data row4 col0" >46-50</td>
#                         <td id="T_89fb2_row4_col1" class="data row4 col1" >F</td>
#                         <td id="T_89fb2_row4_col2" class="data row4 col2" >6743393.000000</td>
#                         <td id="T_89fb2_row4_col3" class="data row4 col3" >693</td>
#                         <td id="T_89fb2_row4_col4" class="data row4 col4" >9730.725830</td>
#                         <td id="T_89fb2_row4_col5" class="data row4 col5" >6.346775</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row5_col0" class="data row5 col0" >36-45</td>
#                         <td id="T_89fb2_row5_col1" class="data row5 col1" >M</td>
#                         <td id="T_89fb2_row5_col2" class="data row5 col2" >6635038.000000</td>
#                         <td id="T_89fb2_row5_col3" class="data row5 col3" >705</td>
#                         <td id="T_89fb2_row5_col4" class="data row5 col4" >9411.401418</td>
#                         <td id="T_89fb2_row5_col5" class="data row5 col5" >6.244793</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row6_col0" class="data row6 col0" >51-55</td>
#                         <td id="T_89fb2_row6_col1" class="data row6 col1" >F</td>
#                         <td id="T_89fb2_row6_col2" class="data row6 col2" >5385208.000000</td>
#                         <td id="T_89fb2_row6_col3" class="data row6 col3" >553</td>
#                         <td id="T_89fb2_row6_col4" class="data row6 col4" >9738.169982</td>
#                         <td id="T_89fb2_row6_col5" class="data row6 col5" >5.068472</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row7_col0" class="data row7 col0" >18-25</td>
#                         <td id="T_89fb2_row7_col1" class="data row7 col1" >M</td>
#                         <td id="T_89fb2_row7_col2" class="data row7 col2" >5353729.000000</td>
#                         <td id="T_89fb2_row7_col3" class="data row7 col3" >574</td>
#                         <td id="T_89fb2_row7_col4" class="data row7 col4" >9327.054007</td>
#                         <td id="T_89fb2_row7_col5" class="data row7 col5" >5.038845</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row8_col0" class="data row8 col0" >51-55</td>
#                         <td id="T_89fb2_row8_col1" class="data row8 col1" >M</td>
#                         <td id="T_89fb2_row8_col2" class="data row8 col2" >2876269.000000</td>
#                         <td id="T_89fb2_row8_col3" class="data row8 col3" >277</td>
#                         <td id="T_89fb2_row8_col4" class="data row8 col4" >10383.642599</td>
#                         <td id="T_89fb2_row8_col5" class="data row8 col5" >2.707099</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row9_col0" class="data row9 col0" >46-50</td>
#                         <td id="T_89fb2_row9_col1" class="data row9 col1" >M</td>
#                         <td id="T_89fb2_row9_col2" class="data row9 col2" >2464451.000000</td>
#                         <td id="T_89fb2_row9_col3" class="data row9 col3" >290</td>
#                         <td id="T_89fb2_row9_col4" class="data row9 col4" >8498.106897</td>
#                         <td id="T_89fb2_row9_col5" class="data row9 col5" >2.319502</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row10_col0" class="data row10 col0" >55+</td>
#                         <td id="T_89fb2_row10_col1" class="data row10 col1" >F</td>
#                         <td id="T_89fb2_row10_col2" class="data row10 col2" >2404931.000000</td>
#                         <td id="T_89fb2_row10_col3" class="data row10 col3" >272</td>
#                         <td id="T_89fb2_row10_col4" class="data row10 col4" >8841.658088</td>
#                         <td id="T_89fb2_row10_col5" class="data row10 col5" >2.263483</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row11_col0" class="data row11 col0" >55+</td>
#                         <td id="T_89fb2_row11_col1" class="data row11 col1" >M</td>
#                         <td id="T_89fb2_row11_col2" class="data row11 col2" >1676056.000000</td>
#                         <td id="T_89fb2_row11_col3" class="data row11 col3" >155</td>
#                         <td id="T_89fb2_row11_col4" class="data row11 col4" >10813.264516</td>
#                         <td id="T_89fb2_row11_col5" class="data row11 col5" >1.577477</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row12_col0" class="data row12 col0" >0-17</td>
#                         <td id="T_89fb2_row12_col1" class="data row12 col1" >F</td>
#                         <td id="T_89fb2_row12_col2" class="data row12 col2" >1441409.000000</td>
#                         <td id="T_89fb2_row12_col3" class="data row12 col3" >162</td>
#                         <td id="T_89fb2_row12_col4" class="data row12 col4" >8897.586420</td>
#                         <td id="T_89fb2_row12_col5" class="data row12 col5" >1.356631</td>
#             </tr>
#             <tr>
#                                 <td id="T_89fb2_row13_

# %%
fig,ax=plt.subplots(2,1)
fig.set_figwidth(40)
fig.set_figheight(30)
Region_sale_info=data.groupby(['Zone','State','Gender'], as_index=False)['Amount'].sum().sort_values(by='Zone',ascending=False)
Region_sale_info_pivot=Region_sale_info.pivot(index=['Zone','State'],columns='Gender',values='Amount')
sns.set(font_scale=1.5)
sns.barplot(x='Zone',y='Amount',data=data,ax=ax[0])
sns.barplot(x='State',y='Amount',data=data,ax=ax[1])
#ax[1].tick_params(axis='x', rotation=90)
Region_sale_info_pivot
# Out:
# Gender                               F          M
# Zone     State
# Central  Delhi              8264499.45  3339320.0
#          Madhya Pradesh     5301046.00  2800096.0
#          Uttar Pradesh     13662105.00  5712863.0
#          Uttarakhand        1593018.00   927926.0
# Eastern  Bihar              2819281.00  1203476.0
#          Jharkhand          1954275.00  1072181.0
# Northern Haryana            3198296.00  1021879.0
#          Himachal Pradesh   3163299.00  1800069.0
#          Punjab              950267.00   575533.0
#          Rajasthan          1243444.00   665965.0
# Southern Andhra�Pradesh     5511219.99  2525927.0
#          Karnataka          9933966.00  3589574.0
#          Kerala             2644087.99  1250404.0
#          Telangana           703814.00   447676.0
# Western  Gujarat            2832262.00  1113820.0
#          Maharashtra       10560976.00  3866567.0
# C:\Users\harshad.korochikar\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\harshad.korochikar\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0, flags=flags)
